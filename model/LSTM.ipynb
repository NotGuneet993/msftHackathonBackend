# %%
import os
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split

# -----------------------
# DEVICE SETUP
# -----------------------
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")

# -----------------------
# LABELS
# -----------------------
label_map = {
    "good": 0,
    "bothknees": 1,
    "buttwink": 2,
    "halfsquat": 3,
    "leanforward": 4,
    "leftknee": 5,
    "rightknee": 6
}

# -----------------------
# CUSTOM DATASET
# -----------------------
class SquatDataset(Dataset):
    def __init__(self, csv_dir, label_map, target_len=74):
        self.csv_dir = csv_dir
        self.files = [f for f in os.listdir(csv_dir) if f.endswith(".csv")]
        self.label_map = label_map
        self.target_len = target_len

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        fname = self.files[idx]
        label_str = fname.split("_")[0].lower()
        label = self.label_map[label_str]

        df = pd.read_csv(os.path.join(self.csv_dir, fname))
        df = df.select_dtypes(include=[np.number])
        data = df.to_numpy()

        if data.shape[0] > self.target_len:
            data = data[:self.target_len]
        elif data.shape[0] < self.target_len:
            pad_len = self.target_len - data.shape[0]
            pad = np.zeros((pad_len, data.shape[1]))
            data = np.vstack((data, pad))

        data = torch.tensor(data, dtype=torch.float32)
        label = torch.tensor(label, dtype=torch.long)
        return data, label

# -----------------------
# MODEL
# -----------------------
class LSTMSquatClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

        for name, param in self.lstm.named_parameters():
            if 'weight' in name:
                nn.init.xavier_uniform_(param)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        return self.fc(hn[-1])

# -----------------------
# TRAINING FUNCTION
# -----------------------
def train(model, train_loader, val_loader, optimizer, criterion, epochs):
    model.train()
    for epoch in range(epochs):
        total_loss, correct, total = 0, 0, 0

        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            output = model(X_batch)

            if torch.isnan(output).any() or torch.isnan(X_batch).any():
                print("⚠️ NaNs detected — skipping batch")
                continue

            loss = criterion(output, y_batch)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            total_loss += loss.item()
            preds = output.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)

        train_acc = correct / total if total > 0 else 0
        val_acc = evaluate(model, val_loader)
        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {total_loss:.4f} | Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")

# -----------------------
# EVALUATION FUNCTION
# -----------------------
def evaluate(model, dataloader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for X_batch, y_batch in dataloader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            output = model(X_batch)
            preds = output.argmax(dim=1)
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)
    model.train()
    return correct / total if total > 0 else 0

# -----------------------
# MAIN
# -----------------------
if __name__ == "__main__":
    csv_dir = "../outputs_normalized"
    full_dataset = SquatDataset(csv_dir, label_map)

    # Stratified split: train (80%) + temp (20%)
    indices = list(range(len(full_dataset)))
    train_idx, temp_idx = train_test_split(
        indices,
        test_size=0.2,
        stratify=[label_map[f.split("_")[0].lower()] for f in full_dataset.files],
        random_state=42
    )

    # Stratified split: val (10%) + test (10%) from temp
    val_idx, test_idx = train_test_split(
        temp_idx,
        test_size=0.5,
        stratify=[label_map[full_dataset.files[i].split("_")[0].lower()] for i in temp_idx],
        random_state=42
    )

    # Datasets & Loaders
    train_dataset = Subset(full_dataset, train_idx)
    val_dataset = Subset(full_dataset, val_idx)
    test_dataset = Subset(full_dataset, test_idx)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32)
    test_loader = DataLoader(test_dataset, batch_size=32)

    # Model
    sample_input, _ = full_dataset[0]
    input_size = sample_input.shape[1]

    model = LSTMSquatClassifier(input_size=input_size, hidden_size=64, num_classes=7).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    train(model, train_loader, val_loader, optimizer, criterion, epochs=200)
# Out:
# Using device: mps
# Epoch 1/200 | Train Loss: 26.4863 | Train Acc: 0.3102 | Val Acc: 0.3333
# Epoch 2/200 | Train Loss: 25.6953 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 3/200 | Train Loss: 25.5524 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 4/200 | Train Loss: 25.3633 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 5/200 | Train Loss: 25.2498 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 6/200 | Train Loss: 24.9527 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 7/200 | Train Loss: 24.6096 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 8/200 | Train Loss: 24.1742 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 9/200 | Train Loss: 23.8622 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 10/200 | Train Loss: 23.4393 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 11/200 | Train Loss: 23.0292 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 12/200 | Train Loss: 23.0066 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 13/200 | Train Loss: 22.8109 | Train Acc: 0.3333 | Val Acc: 0.3333
# Epoch 14/200 | Train Loss: 22.7743 | Train Acc: 0.3426 | Val Acc: 0.3519
# Epoch 15/200 | Train Loss: 22.4256 | Train Acc: 0.3611 | Val Acc: 0.4074
# Epoch 16/200 | Train Loss: 22.0088 | Train Acc: 0.3750 | Val Acc: 0.4444
# Epoch 17/200 | Train Loss: 21.4325 | Train Acc: 0.4282 | Val Acc: 0.4444
# Epoch 18/200 | Train Loss: 21.4374 | Train Acc: 0.4097 | Val Acc: 0.5000
# Epoch 19/200 | Train Loss: 20.8601 | Train Acc: 0.4167 | Val Acc: 0.5185
# Epoch 20/200 | Train Loss: 20.5340 | Train Acc: 0.4514 | Val Acc: 0.5000
# Epoch 21/200 | Train Loss: 20.4914 | Train Acc: 0.4514 | Val Acc: 0.4444
# Epoch 22/200 | Train Loss: 20.4081 | Train Acc: 0.4792 | Val Acc: 0.5370
# Epoch 23/200 | Train Loss: 19.5594 | Train Acc: 0.5162 | Val Acc: 0.5556
# Epoch 24/200 | Train Loss: 19.7233 | Train Acc: 0.5116 | Val Acc: 0.6111
# Epoch 25/200 | Train Loss: 19.5522 | Train Acc: 0.5231 | Val Acc: 0.6481
# Epoch 26/200 | Train Loss: 19.0116 | Train Acc: 0.5648 | Val Acc: 0.5741
# Epoch 27/200 | Train Loss: 19.0062 | Train Acc: 0.5579 | Val Acc: 0.6296
# Epoch 28/200 | Train Loss: 18.5692 | Train Acc: 0.5532 | Val Acc: 0.4630
# Epoch 29/200 | Train Loss: 19.3101 | Train Acc: 0.4722 | Val Acc: 0.5556
# Epoch 30/200 | Train Loss: 18.7741 | Train Acc: 0.5139 | Val Acc: 0.6111
# Epoch 31/200 | Train Loss: 18.7023 | Train Acc: 0.5463 | Val Acc: 0.5926
# Epoch 32/200 | Train Loss: 18.9383 | Train Acc: 0.5417 | Val Acc: 0.5000
# Epoch 33/200 | Train Loss: 21.5099 | Train Acc: 0.4977 | Val Acc: 0.6481
# Epoch 34/200 | Train Loss: 18.1750 | Train Acc: 0.6181 | Val Acc: 0.6111
# Epoch 35/200 | Train Loss: 18.2270 | Train Acc: 0.5278 | Val Acc: 0.6481
# Epoch 36/200 | Train Loss: 17.6895 | Train Acc: 0.5718 | Val Acc: 0.6481
# Epoch 37/200 | Train Loss: 18.5780 | Train Acc: 0.5069 | Val Acc: 0.6481
# Epoch 38/200 | Train Loss: 18.5873 | Train Acc: 0.6042 | Val Acc: 0.6111
# Epoch 39/200 | Train Loss: 17.7745 | Train Acc: 0.6157 | Val Acc: 0.6852
# Epoch 40/200 | Train Loss: 17.4239 | Train Acc: 0.6065 | Val Acc: 0.6481
# Epoch 41/200 | Train Loss: 16.9884 | Train Acc: 0.6134 | Val Acc: 0.6111
# Epoch 42/200 | Train Loss: 17.1425 | Train Acc: 0.6181 | Val Acc: 0.5926
# Epoch 43/200 | Train Loss: 16.7680 | Train Acc: 0.6366 | Val Acc: 0.7593
# Epoch 44/200 | Train Loss: 16.7983 | Train Acc: 0.6389 | Val Acc: 0.7222
# Epoch 45/200 | Train Loss: 16.4317 | Train Acc: 0.6481 | Val Acc: 0.7037
# Epoch 46/200 | Train Loss: 15.6687 | Train Acc: 0.6505 | Val Acc: 0.7407
# Epoch 47/200 | Train Loss: 16.1294 | Train Acc: 0.6551 | Val Acc: 0.7593
# Epoch 48/200 | Train Loss: 15.9811 | Train Acc: 0.6435 | Val Acc: 0.7037
# Epoch 49/200 | Train Loss: 15.2841 | Train Acc: 0.6690 | Val Acc: 0.7037
# Epoch 50/200 | Train Loss: 15.4489 | Train Acc: 0.6505 | Val Acc: 0.7593
# Epoch 51/200 | Train Loss: 14.8531 | Train Acc: 0.6667 | Val Acc: 0.7222
# Epoch 52/200 | Train Loss: 14.6450 | Train Acc: 0.6782 | Val Acc: 0.7593
# Epoch 53/200 | Train Loss: 14.4743 | Train Acc: 0.6806 | Val Acc: 0.7593
# Epoch 54/200 | Train Loss: 15.1738 | Train Acc: 0.6620 | Val Acc: 0.7407
# Epoch 55/200 | Train Loss: 15.9044 | Train Acc: 0.6343 | Val Acc: 0.7407
# Epoch 56/200 | Train Loss: 14.2491 | Train Acc: 0.6713 | Val Acc: 0.7593
# Epoch 57/200 | Train Loss: 16.3613 | Train Acc: 0.6551 | Val Acc: 0.7778
# Epoch 58/200 | Train Loss: 15.0453 | Train Acc: 0.6389 | Val Acc: 0.7407
# Epoch 59/200 | Train Loss: 14.6424 | Train Acc: 0.6875 | Val Acc: 0.7778
# Epoch 60/200 | Train Loss: 13.9183 | Train Acc: 0.6991 | Val Acc: 0.7593
# Epoch 61/200 | Train Loss: 13.6487 | Train Acc: 0.6759 | Val Acc: 0.7593
# Epoch 62/200 | Train Loss: 14.4878 | Train Acc: 0.6644 | Val Acc: 0.7778
# Epoch 63/200 | Train Loss: 13.7029 | Train Acc: 0.7014 | Val Acc: 0.6852
# Epoch 64/200 | Train Loss: 13.6828 | Train Acc: 0.6782 | Val Acc: 0.7222
# Epoch 65/200 | Train Loss: 13.0962 | Train Acc: 0.6875 | Val Acc: 0.7963
# Epoch 66/200 | Train Loss: 13.7495 | Train Acc: 0.6759 | Val Acc: 0.7593
# Epoch 67/200 | Train Loss: 12.4055 | Train Acc: 0.7153 | Val Acc: 0.7963
# Epoch 68/200 | Train Loss: 13.3401 | Train Acc: 0.6713 | Val Acc: 0.7963
# Epoch 69/200 | Train Loss: 12.6214 | Train Acc: 0.7060 | Val Acc: 0.7778
# Epoch 70/200 | Train Loss: 13.7512 | Train Acc: 0.6759 | Val Acc: 0.7778
# Epoch 71/200 | Train Loss: 13.2980 | Train Acc: 0.6875 | Val Acc: 0.7222
# Epoch 72/200 | Train Loss: 13.9023 | Train Acc: 0.6736 | Val Acc: 0.7222
# Epoch 73/200 | Train Loss: 13.0124 | Train Acc: 0.6574 | Val Acc: 0.7407
# Epoch 74/200 | Train Loss: 13.3650 | Train Acc: 0.6782 | Val Acc: 0.7222
# Epoch 75/200 | Train Loss: 12.6739 | Train Acc: 0.6759 | Val Acc: 0.7778
# Epoch 76/200 | Train Loss: 11.5168 | Train Acc: 0.7176 | Val Acc: 0.8148
# Epoch 77/200 | Train Loss: 11.2610 | Train Acc: 0.7338 | Val Acc: 0.7778
# Epoch 78/200 | Train Loss: 11.4869 | Train Acc: 0.7083 | Val Acc: 0.7963
# Epoch 79/200 | Train Loss: 11.7961 | Train Acc: 0.7037 | Val Acc: 0.7407
# Epoch 80/200 | Train Loss: 11.8874 | Train Acc: 0.7106 | Val Acc: 0.7593
# Epoch 81/200 | Train Loss: 12.4902 | Train Acc: 0.6921 | Val Acc: 0.7778
# Epoch 82/200 | Train Loss: 11.7448 | Train Acc: 0.7106 | Val Acc: 0.7778
# Epoch 83/200 | Train Loss: 11.0774 | Train Acc: 0.7315 | Val Acc: 0.8148
# Epoch 84/200 | Train Loss: 10.5089 | Train Acc: 0.7454 | Val Acc: 0.7222
# Epoch 85/200 | Train Loss: 11.5668 | Train Acc: 0.7245 | Val Acc: 0.8333
# Epoch 86/200 | Train Loss: 9.9664 | Train Acc: 0.7731 | Val Acc: 0.8148
# Epoch 87/200 | Train Loss: 12.1006 | Train Acc: 0.7315 | Val Acc: 0.7963
# Epoch 88/200 | Train Loss: 9.2346 | Train Acc: 0.7801 | Val Acc: 0.8704
# Epoch 89/200 | Train Loss: 8.7125 | Train Acc: 0.7847 | Val Acc: 0.8333
# Epoch 90/200 | Train Loss: 8.6083 | Train Acc: 0.7986 | Val Acc: 0.8889
# Epoch 91/200 | Train Loss: 10.2994 | Train Acc: 0.7662 | Val Acc: 0.8148
# Epoch 92/200 | Train Loss: 8.7107 | Train Acc: 0.8056 | Val Acc: 0.8704
# Epoch 93/200 | Train Loss: 9.4442 | Train Acc: 0.7546 | Val Acc: 0.8519
# Epoch 94/200 | Train Loss: 8.9414 | Train Acc: 0.7593 | Val Acc: 0.8889
# Epoch 95/200 | Train Loss: 8.5945 | Train Acc: 0.8056 | Val Acc: 0.8519
# Epoch 96/200 | Train Loss: 7.3551 | Train Acc: 0.8472 | Val Acc: 0.9074
# Epoch 97/200 | Train Loss: 7.7334 | Train Acc: 0.8472 | Val Acc: 0.8704
# Epoch 98/200 | Train Loss: 7.9716 | Train Acc: 0.8264 | Val Acc: 0.8889
# Epoch 99/200 | Train Loss: 6.9049 | Train Acc: 0.8519 | Val Acc: 0.9259
# Epoch 100/200 | Train Loss: 6.9103 | Train Acc: 0.8380 | Val Acc: 0.8889
# Epoch 101/200 | Train Loss: 6.8171 | Train Acc: 0.8542 | Val Acc: 0.8889
# Epoch 102/200 | Train Loss: 6.9914 | Train Acc: 0.8773 | Val Acc: 0.8889
# Epoch 103/200 | Train Loss: 7.3818 | Train Acc: 0.8565 | Val Acc: 0.9259
# Epoch 104/200 | Train Loss: 7.0701 | Train Acc: 0.8403 | Val Acc: 0.9444
# Epoch 105/200 | Train Loss: 6.9082 | Train Acc: 0.8310 | Val Acc: 0.8519
# Epoch 106/200 | Train Loss: 5.8356 | Train Acc: 0.8634 | Val Acc: 0.8704
# Epoch 107/200 | Train Loss: 6.3072 | Train Acc: 0.8657 | Val Acc: 0.9259
# Epoch 108/200 | Train Loss: 5.8451 | Train Acc: 0.8912 | Val Acc: 0.9259
# Epoch 109/200 | Train Loss: 5.9123 | Train Acc: 0.8935 | Val Acc: 0.9444
# Epoch 110/200 | Train Loss: 6.5121 | Train Acc: 0.8611 | Val Acc: 0.9444
# Epoch 111/200 | Train Loss: 6.9601 | Train Acc: 0.8634 | Val Acc: 0.9074
# Epoch 112/200 | Train Loss: 5.9209 | Train Acc: 0.8889 | Val Acc: 0.9074
# Epoch 113/200 | Train Loss: 6.1194 | Train Acc: 0.8704 | Val Acc: 0.9444
# Epoch 114/200 | Train Loss: 5.1386 | Train Acc: 0.8889 | Val Acc: 0.8889
# Epoch 115/200 | Train Loss: 5.1847 | Train Acc: 0.8935 | Val Acc: 0.9259
# Epoch 116/200 | Train Loss: 4.9686 | Train Acc: 0.9051 | Val Acc: 0.9259
# Epoch 117/200 | Train Loss: 5.0573 | Train Acc: 0.8819 | Val Acc: 0.9259
# Epoch 118/200 | Train Loss: 4.9371 | Train Acc: 0.9005 | Val Acc: 0.9630
# Epoch 119/200 | Train Loss: 4.6729 | Train Acc: 0.9074 | Val Acc: 0.9074
# Epoch 120/200 | Train Loss: 5.0715 | Train Acc: 0.9051 | Val Acc: 0.8704
# Epoch 121/200 | Train Loss: 4.6757 | Train Acc: 0.9120 | Val Acc: 0.9074
# Epoch 122/200 | Train Loss: 4.9341 | Train Acc: 0.9120 | Val Acc: 0.8519
# Epoch 123/200 | Train Loss: 5.8844 | Train Acc: 0.8750 | Val Acc: 0.9074
# Epoch 124/200 | Train Loss: 4.3457 | Train Acc: 0.9190 | Val Acc: 0.9444
# Epoch 125/200 | Train Loss: 5.5651 | Train Acc: 0.8750 | Val Acc: 0.8889
# Epoch 126/200 | Train Loss: 4.9228 | Train Acc: 0.9028 | Val Acc: 0.9444
# Epoch 127/200 | Train Loss: 4.2490 | Train Acc: 0.9213 | Val Acc: 0.9259
# Epoch 128/200 | Train Loss: 7.5197 | Train Acc: 0.8310 | Val Acc: 0.9074
# Epoch 129/200 | Train Loss: 6.9905 | Train Acc: 0.8426 | Val Acc: 0.9630
# Epoch 130/200 | Train Loss: 4.5799 | Train Acc: 0.9190 | Val Acc: 0.9259
# Epoch 131/200 | Train Loss: 4.2193 | Train Acc: 0.9306 | Val Acc: 0.9444
# Epoch 132/200 | Train Loss: 4.3378 | Train Acc: 0.9375 | Val Acc: 0.9259
# Epoch 133/200 | Train Loss: 3.5569 | Train Acc: 0.9352 | Val Acc: 0.9630
# Epoch 134/200 | Train Loss: 3.6785 | Train Acc: 0.9352 | Val Acc: 0.9259
# Epoch 135/200 | Train Loss: 5.7260 | Train Acc: 0.8681 | Val Acc: 0.9074
# Epoch 136/200 | Train Loss: 5.8035 | Train Acc: 0.8819 | Val Acc: 0.9444
# Epoch 137/200 | Train Loss: 3.7422 | Train Acc: 0.9468 | Val Acc: 0.9630
# Epoch 138/200 | Train Loss: 4.4397 | Train Acc: 0.9213 | Val Acc: 0.9630
# Epoch 139/200 | Train Loss: 3.6646 | Train Acc: 0.9398 | Val Acc: 0.9630
# Epoch 140/200 | Train Loss: 4.4085 | Train Acc: 0.8935 | Val Acc: 0.9444
# Epoch 141/200 | Train Loss: 4.1748 | Train Acc: 0.9213 | Val Acc: 0.9444
# Epoch 142/200 | Train Loss: 3.8167 | Train Acc: 0.9144 | Val Acc: 0.9444
# Epoch 143/200 | Train Loss: 3.2589 | Train Acc: 0.9444 | Val Acc: 0.9630
# Epoch 144/200 | Train Loss: 2.9667 | Train Acc: 0.9514 | Val Acc: 0.9815
# Epoch 145/200 | Train Loss: 3.5101 | Train Acc: 0.9329 | Val Acc: 0.9259
# Epoch 146/200 | Train Loss: 3.2700 | Train Acc: 0.9329 | Val Acc: 0.9630
# Epoch 147/200 | Train Loss: 3.8240 | Train Acc: 0.9282 | Val Acc: 0.9630
# Epoch 148/200 | Train Loss: 3.1432 | Train Acc: 0.9398 | Val Acc: 0.9815
# Epoch 149/200 | Train Loss: 3.4364 | Train Acc: 0.9329 | Val Acc: 0.8889
# Epoch 150/200 | Train Loss: 4.1831 | Train Acc: 0.9097 | Val Acc: 0.9630
# Epoch 151/200 | Train Loss: 3.3397 | Train Acc: 0.9329 | Val Acc: 0.9815
# Epoch 152/200 | Train Loss: 3.0598 | Train Acc: 0.9398 | Val Acc: 0.9444
# Epoch 153/200 | Train Loss: 2.9205 | Train Acc: 0.9537 | Val Acc: 0.9815
# Epoch 154/200 | Train Loss: 2.6055 | Train Acc: 0.9560 | Val Acc: 0.9074
# Epoch 155/200 | Train Loss: 2.6571 | Train Acc: 0.9583 | Val Acc: 0.9815
# Epoch 156/200 | Train Loss: 3.1941 | Train Acc: 0.9329 | Val Acc: 0.9815
# Epoch 157/200 | Train Loss: 2.9996 | Train Acc: 0.9352 | Val Acc: 0.9630
# Epoch 158/200 | Train Loss: 3.5745 | Train Acc: 0.9352 | Val Acc: 0.9630
# Epoch 159/200 | Train Loss: 2.2874 | Train Acc: 0.9491 | Val Acc: 0.9630
# Epoch 160/200 | Train Loss: 2.3916 | Train Acc: 0.9560 | Val Acc: 0.9630
# Epoch 161/200 | Train Loss: 2.4550 | Train Acc: 0.9583 | Val Acc: 0.9815
# Epoch 162/200 | Train Loss: 2.2544 | Train Acc: 0.9560 | Val Acc: 0.9630
# Epoch 163/200 | Train Loss: 2.4383 | Train Acc: 0.9537 | Val Acc: 0.9630
# Epoch 164/200 | Train Loss: 2.1592 | Train Acc: 0.9583 | Val Acc: 0.9815
# Epoch 165/200 | Train Loss: 2.9468 | Train Acc: 0.9236 | Val Acc: 0.9444
# Epoch 166/200 | Train Loss: 2.9972 | Train Acc: 0.9398 | Val Acc: 0.9815
# Epoch 167/200 | Train Loss: 2.4834 | Train Acc: 0.9491 | Val Acc: 0.9630
# Epoch 168/200 | Train Loss: 2.9105 | Train Acc: 0.9352 | Val Acc: 0.9444
# Epoch 169/200 | Train Loss: 2.2895 | Train Acc: 0.9583 | Val Acc: 0.9815
# Epoch 170/200 | Train Loss: 2.9417 | Train Acc: 0.9421 | Val Acc: 0.9630
# Epoch 171/200 | Train Loss: 2.6332 | Train Acc: 0.9398 | Val Acc: 0.9259
# Epoch 172/200 | Train Loss: 2.5052 | Train Acc: 0.9444 | Val Acc: 0.9630
# Epoch 173/200 | Train Loss: 2.5533 | Train Acc: 0.9560 | Val Acc: 0.9815
# Epoch 174/200 | Train Loss: 2.3006 | Train Acc: 0.9630 | Val Acc: 1.0000
# Epoch 175/200 | Train Loss: 1.9751 | Train Acc: 0.9653 | Val Acc: 1.0000
# Epoch 176/200 | Train Loss: 1.7062 | Train Acc: 0.9653 | Val Acc: 0.9815
# Epoch 177/200 | Train Loss: 1.9660 | Train Acc: 0.9676 | Val Acc: 0.9444
# Epoch 178/200 | Train Loss: 2.3864 | Train Acc: 0.9537 | Val Acc: 0.9815
# Epoch 179/200 | Train Loss: 1.8597 | Train Acc: 0.9653 | Val Acc: 1.0000
# Epoch 180/200 | Train Loss: 2.9111 | Train Acc: 0.9398 | Val Acc: 0.9815
# Epoch 181/200 | Train Loss: 2.3394 | Train Acc: 0.9560 | Val Acc: 1.0000
# Epoch 182/200 | Train Loss: 2.7953 | Train Acc: 0.9537 | Val Acc: 0.9259
# Epoch 183/200 | Train Loss: 3.6010 | Train Acc: 0.9259 | Val Acc: 0.9630
# Epoch 184/200 | Train Loss: 2.8331 | Train Acc: 0.9491 | Val Acc: 0.9630
# Epoch 185/200 | Train Loss: 4.2524 | Train Acc: 0.9144 | Val Acc: 0.9444
# Epoch 186/200 | Train Loss: 1.7307 | Train Acc: 0.9653 | Val Acc: 0.9630
# Epoch 187/200 | Train Loss: 8.2459 | Train Acc: 0.8287 | Val Acc: 0.9074
# Epoch 188/200 | Train Loss: 3.7013 | Train Acc: 0.9190 | Val Acc: 0.9630
# Epoch 189/200 | Train Loss: 2.3344 | Train Acc: 0.9468 | Val Acc: 0.9815
# Epoch 190/200 | Train Loss: 2.6277 | Train Acc: 0.9468 | Val Acc: 0.9630
# Epoch 191/200 | Train Loss: 2.6241 | Train Acc: 0.9537 | Val Acc: 0.9815
# Epoch 192/200 | Train Loss: 1.4766 | Train Acc: 0.9676 | Val Acc: 0.9444
# Epoch 193/200 | Train Loss: 1.7773 | Train Acc: 0.9583 | Val Acc: 1.0000
# Epoch 194/200 | Train Loss: 1.9212 | Train Acc: 0.9630 | Val Acc: 0.9630
# Epoch 195/200 | Train Loss: 2.1399 | Train Acc: 0.9514 | Val Acc: 0.9815
# Epoch 196/200 | Train Loss: 1.3684 | Train Acc: 0.9722 | Val Acc: 0.9815
# Epoch 197/200 | Train Loss: 2.3778 | Train Acc: 0.9444 | Val Acc: 0.9630
# Epoch 198/200 | Train Loss: 3.0498 | Train Acc: 0.9375 | Val Acc: 0.9815
# Epoch 199/200 | Train Loss: 2.0403 | Train Acc: 0.9653 | Val Acc: 0.9815
# Epoch 200/200 | Train Loss: 1.5493 | Train Acc: 0.9699 | Val Acc: 0.9815

# %%
import os
import pandas as pd
import numpy as np

csv_dir = "../outputs_normalized"
bad_files = []

for fname in os.listdir(csv_dir):
    if not fname.endswith(".csv"):
        continue

    path = os.path.join(csv_dir, fname)
    try:
        df = pd.read_csv(path)

        # Keep only numeric columns
        df = df.select_dtypes(include=[np.number])

        if df.shape[1] == 0:
            print(f"❌ No numeric columns: {fname}")
            bad_files.append(fname)
            continue

        if df.isna().all(axis=1).any():
            print(f"❌ Row(s) full of NaNs: {fname}")
            bad_files.append(fname)
            continue

        if df.dropna().empty:
            print(f"❌ All rows have NaNs or are empty: {fname}")
            bad_files.append(fname)
            continue

    except Exception as e:
        print(f"❌ Failed to process {fname}: {e}")
        bad_files.append(fname)

print("\n🔍 Scan complete.")
print(f"Total files scanned: {len(os.listdir(csv_dir))}")
print(f"Bad files found: {len(bad_files)}")
# Out:
# 🔍 Scan complete.
# Total files scanned: 361
# Bad files found: 0

# %%
import os
import shutil

# Path to the directory
csv_dir = "../outputs_normalized"

# Get list of all CSV files
all_files = [f for f in os.listdir(csv_dir) if f.endswith(".csv")]

# Track how many were duplicated
dup_count = 0

for filename in all_files:
    if not filename.lower().startswith("good_"):
        original_path = os.path.join(csv_dir, filename)

        # Construct a new filename
        name, ext = os.path.splitext(filename)
        new_filename = f"{name}_dup{ext}"
        new_path = os.path.join(csv_dir, new_filename)

        # Copy the file
        shutil.copyfile(original_path, new_path)
        dup_count += 1

print(f"✅ Duplicated {dup_count} files.")
# Out:
# ✅ Duplicated 180 files.
